# %% [markdown]
# 카테고리 : 방송
#
# 1. 다음 url과 네이버 url이 동일한 인물인지 확인
# 2. 동일하지 않으면 무조건 다음 기준으로 쿼리 짜고, 올바른 네이버 url 찾아서 시트 수정해주기 + 노란색으로 표시
# 3. 나머지는 하시던대로 솔라쿼리 짜시면 됨당 (아무것도 입력 안하고 엔터하면 title:"이름" AND type:news 자동 입력됨)

# %%
import pandas as pd
from selenium import webdriver
from tqdm.notebook import tqdm
import time
from webdriver_manager.chrome import ChromeDriverManager

# 아웃풋 다 노출되게
def set_pandas_display_options() -> None:
    display = pd.options.display
    display.max_columns = 100
    display.max_rows = 100
    display.max_colwidth = 199
    display.width = None
set_pandas_display_options()

# 시트에서 할만큼 이름, 다음 url, 네이버 url 복사해서 붙여넣기
df = pd.read_excel("tv_sample.xlsx")

name = df['name']
daum = df['daum']
naver = df['naver']

display(df)
# Out:
#            name                                                 daum  \
# 0       크리스틴 레만  https://100.daum.net/encyclopedia/view/33XXXXX29246
# 1         에릭 라딘  https://100.daum.net/encyclopedia/view/33XXXXX42142
# 2       브렌단 섹스톤  https://100.daum.net/encyclopedia/view/33XXXXX37779
# 3      칼럼 키스 레니  https://100.daum.net/encyclopedia/view/33XXXXX38118
# 4       케이티 핀들리  https://100.daum.net/encyclopedia/view/33XXX1277156
# 5        리암 제임스  https://100.daum.net/encyclopedia/view/33XXXX715543
# 6         게리 초크  https://100.daum.net/encyclopedia/view/33XXXX723388
# 7    브랜든 제이 맥라렌  https://100.daum.net/encyclopedia/view/33XXXX716845
# 8         에반 버드  https://100.daum.net/encyclopedia/view/33XXX1221454
# 9        리차드 하몬  https://100.daum.net/encyclopedia/view/33XXXX776735
# 10   기니비에브 부에크너  https://100.daum.net/encyclopedia/view/33XXXXX40386
# 11        앨런 데일  https://100.daum.net/encyclopedia/view/33XXXXX69069
# 12      패트릭 길모어  https://100.daum.net/encyclopedia/view/33XXXX820061
# 13      피터 키라니스  https://100.daum.net/encyclopedia/view/33XXXX706606
# 14       애슐리 존슨  https://100.daum.net/encyclopedia/view/33XXXXX38504
# 15       콜린 로렌스  https://100.daum.net/encyclopedia/view/33XXXX744174
# 16       매튜 맥카울  https://100.daum.net/encyclopedia/view/33XXXX846448
# 17      앤드류 에어리  https://100.daum.net/encyclopedia/view/33XXXXX69920
# 18       마크 모시즈  https://100.daum.net/encyclopedia/view/33XXXXX24593
# 19      피터 사스가드  https://100.daum.net/encyclopedia/view/33XXXXX24298
# 20     엘리어스 코티스  https://100.daum.net/encyclopedia/view/33XXXXX38600
# 21     에이미 세이메츠  https://100.daum.net/encyclopedia/view/33XXXX751282
# 22  벡스 테일러 클라우스  https://100.daum.net/encyclopedia/view/33XXX1519048
# 23    줄리아 사라 스톤  https://100.daum.net/encyclopedia/view/33XXXX909448
# 24         휴 딜런  https://100.daum.net/encyclopedia/view/33XXXX875559
# 25      아론 더글러스  https://100.daum.net/encyclopedia/view/33XXXXX72681
# 26         벤 코튼  https://100.daum.net/encyclopedia/view/33XXXX710584
# 27      마이클 코프사  https://100.daum.net/encyclopedia/view/33XXXX688111
# 28      가나가와 히로  https://100.daum.net/encyclopedia/view/33XXXXX37770
# 29      라이언 로빈스  https://100.daum.net/encyclopedia/view/33XXXX823484
# 30      니콜라스 레아  https://100.daum.net/encyclopedia/view/33XXXXX41228
# 31   그레이스 자브리스키  https://100.daum.net/encyclopedia/view/33XXXXX40593
# 32      브렌단 플레처  https://100.daum.net/encyclopedia/view/33XXXX247527
# 33     잉그리드 토런스  https://100.daum.net/encyclopedia/view/33XXXX756567
# 34       소냐 살로마  https://100.daum.net/encyclopedia/view/33XXXX841272
# 35       폴 맥길리온  https://100.daum.net/encyclopedia/view/33XXXX707413
# 36       조나단 워커  https://100.daum.net/encyclopedia/view/33XXXXX76695
# 37        조안 알렌  https://100.daum.net/encyclopedia/view/33XXXXX26747
# 38       이브 하로우  https://100.daum.net/encyclopedia/view/33XXXX787464
# 39        레비 미든  https://100.daum.net/encyclopedia/view/33XXX1672468
# 40       스털링 보먼  https://100.daum.net/encyclopedia/view/33XXXX777175
# 41      마린 아일랜드  https://100.daum.net/encyclopedia/view/33XXXX725160
# 42       서지 하우드  https://100.daum.net/encyclopedia/view/33XXXXX77205
# 43       시아란 힌즈  https://100.daum.net/encyclopedia/view/33XXXXX38251
# 44         폴 레디  https://100.daum.net/encyclopedia/view/33XXXX777123
# 45     아담 나게이티스  https://100.daum.net/encyclopedia/view/33XXX1669025
# 46        니브 닐센  https://100.daum.net/encyclopedia/view/33XXX2178030
# 47        이안 하트  https://100.daum.net/encyclopedia/view/33XXXXX37795
# 48       매튜 맥널티  https://100.daum.net/encyclopedia/view/33XXXX750316
# 49      스케자네 키키  https://100.daum.net/encyclopedia/view/33XXX2158752
#
#                                                                                                                                naver  \
# 0         https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 크리스틴 레만 &os=124035&ie=utf8&key=PeopleService
# 1           https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 에릭 라딘 &os=123763&ie=utf8&key=PeopleService
# 2         https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 브렌단 섹스톤 &os=106574&ie=utf8&key=PeopleService
# 3        https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 칼럼 키스 레니 &os=107223&ie=utf8&key=PeopleService
# 4         https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 케이티 핀들리 &os=557608&ie=utf8&key=PeopleService
# 5          https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 리암 제임스 &os=175901&ie=utf8&key=PeopleService
# 6           https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 게리 초크 &os=271763&ie=utf8&key=PeopleService
# 7                                                                                                                                NaN
# 8                                                                                                                                NaN
# 9          https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 리차드 하몬 &os=483957&ie=utf8&key=PeopleService
# 10     https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 기니비에브 부에크너 &os=111430&ie=utf8&key=PeopleService
# 11          https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 앨런 데일 &os=141255&ie=utf8&key=PeopleService
# 12        https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 패트릭 길모어 &os=252804&ie=utf8&key=PeopleService
# 13        https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 피터 키라니스 &os=277520&ie=utf8&key=PeopleService
# 14         https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 애슐리 존슨 &os=108014&ie=utf8&key=PeopleService
# 15                                                                                                                               NaN
# 16                                                                                                                               NaN
# 17        https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 앤드류 에어리 &os=274976&ie=utf8&key=PeopleService
# 18         https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 마크 모시즈 &os=120357&ie=utf8&key=PeopleService
# 19         https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 피터 사스가드 &os=99491&ie=utf8&key=PeopleService
# 20       https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 엘리어스 코티스 &os=108206&ie=utf8&key=PeopleService
# 21       https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 에이미 세이메츠 &os=567808&ie=utf8&key=PeopleService
# 22  https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 벡스 테일러 클라우스 &os=14238222&ie=utf8&key=PeopleService
# 23     https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 줄리아 사라 스톤 &os=3177298&ie=utf8&key=PeopleService
# 24           https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 휴 딜런 &os=174579&ie=utf8&key=PeopleService
# 25        https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 아론 더글러스 &os=122868&ie=utf8&key=PeopleService
# 26          https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 벤 코튼 &os=2319173&ie=utf8&key=PeopleService
# 27       https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 마이클 코프사 &os=2634647&ie=utf8&key=PeopleService
# 28        https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 가나가와 히로 &os=106565&ie=utf8&key=PeopleService
# 29        https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 라이언 로빈스 &os=181699&ie=utf8&key=PeopleService
# 30        https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 니콜라스 레아 &os=108595&ie=utf8&key=PeopleService
# 31     https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 그레이스 자브리스키 &os=110389&ie=utf8&key=PeopleService
# 32        https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 브렌단 플레처 &os=552893&ie=utf8&key=PeopleService
# 33                                                                                                                               NaN
# 34         https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 소냐 살로마 &os=274325&ie=utf8&key=PeopleService
# 35         https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 폴 맥길리온 &os=219123&ie=utf8&key=PeopleService
# 36                                                                                                                               NaN
# 37          https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 조안 알렌 &os=107200&ie=utf8&key=PeopleService
# 38         https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 이브 하로우 &os=294555&ie=utf8&key=PeopleService
# 39         https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 레비 미든 &os=2457713&ie=utf8&key=PeopleService
# 40         https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 스털링 보먼 &os=318844&ie=utf8&key=PeopleService
# 41        https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 마린 아일랜드 &os=249220&ie=utf8&key=PeopleService
# 42                                                                                                                               NaN
# 43         https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 시아란 힌즈 &os=107502&ie=utf8&key=PeopleService
# 44                                                                                                                               NaN
# 45                                                                                                                               NaN
# 46                                                                                                                               NaN
# 47          https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 이안 하트 &os=106593&ie=utf8&key=PeopleService
# 48         https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 매튜 맥널티 &os=528325&ie=utf8&key=PeopleService
# 49       https://people.search.naver.com/search.naver?where=nexearch&sm=tab_ppn&query= 스케자네 키키 &os=2770298&ie=utf8&key=PeopleService
#
#     solr
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# 42   NaN
# 43   NaN
# 44   NaN
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   NaN

# %%
## 로그인
chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)

pid = 'mycelebsTempUser'
ppw = 'mycelebs!@rookie'
driver.get(f'http://{pid}:{ppw}@dev.mycelebs.com/donut/')
# alert = driver.switch_to_alert()
alert = driver.switch_to.alert
alert.accept()
time.sleep(2.0)

driver.find_element_by_css_selector('#adminId').send_keys('rookie')
driver.find_element_by_css_selector('#adminPw').send_keys('1234')
btn = driver.find_element_by_css_selector('#loginForm > button')
btn.click()

chrome_options = webdriver.ChromeOptions()
profile = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)
profile.execute_script('window.open("about:blank", "_blank");')
    
tabs = profile.window_handles

solr_df = []


for i in tqdm(range(len(df))) :
    try : 
        profile.switch_to_window(tabs[0])
        profile.get(df['daum'].iloc[i])

        profile.switch_to_window(tabs[1])
        profile.get(df['naver'].iloc[i])
    except :
        pass
    
    url = 'http://dev.mycelebs.com/donut/index.php/Verticalanalysis/ShowKeyword'
    driver.get(url)
    
    value = df['name'].iloc[i]
        
    driver.find_element_by_xpath('//*[@id="query"]').clear()
    driver.find_element_by_xpath('//*[@id="query"]').send_keys(f'(content_all:(title:"{value}" AND type:news))')
    driver.find_element_by_xpath('//*[@id="submit_btn"]').click()

    print(df["name"].iloc[i])
    solr_input = input('솔라쿼리를 입력하세요')
    if solr_input == '':
          solr_input = f'(content_all:(title:"{value}" AND type:news))'
    
    solr_ = {'name':df['name'].iloc[i], 'daum':df['daum'].iloc[i], 'naver':df['naver'].iloc[i], 'solr':solr_input}
    solr_df.append(solr_)
    
    
print("DONE !!!!! ")
df = pd.DataFrame(solr_df, columns = ['name', 'daum', 'naver', 'solr'])
df.to_excel("tv_sample.xlsx", index = False, encoding='utf-8-sig')

driver.close()
profile.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/Users/jieun/.wdm/drivers/chromedriver/mac64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/Users/jieun/.wdm/drivers/chromedriver/mac64/91.0.4472.101/chromedriver] found in cache
#   0%|          | 0/50 [00:00<?, ?it/s]
# <ipython-input-2-1c0b1c60a6ca>:29: DeprecationWarning: use driver.switch_to.window instead
#   profile.switch_to_window(tabs[0])
# <ipython-input-2-1c0b1c60a6ca>:32: DeprecationWarning: use driver.switch_to.window instead
#   profile.switch_to_window(tabs[1])
# 크리스틴 레만
# 솔라쿼리를 입력하세요
# 에릭 라딘
# 솔라쿼리를 입력하세요
# 브렌단 섹스톤
# 솔라쿼리를 입력하세요
# 칼럼 키스 레니
# 솔라쿼리를 입력하세요
# 케이티 핀들리
# 솔라쿼리를 입력하세요
# 리암 제임스
# 솔라쿼리를 입력하세요
# 게리 초크
# 솔라쿼리를 입력하세요
# 브랜든 제이 맥라렌
# 솔라쿼리를 입력하세요
# 에반 버드
# 솔라쿼리를 입력하세요
# 리차드 하몬
# 솔라쿼리를 입력하세요
# 기니비에브 부에크너
# 솔라쿼리를 입력하세요
# 앨런 데일
# 솔라쿼리를 입력하세요
# 패트릭 길모어
# 솔라쿼리를 입력하세요
# 피터 키라니스
# 솔라쿼리를 입력하세요
# 애슐리 존슨
# 솔라쿼리를 입력하세요
# 콜린 로렌스
# 솔라쿼리를 입력하세요
# 매튜 맥카울
# 솔라쿼리를 입력하세요
# 앤드류 에어리
# 솔라쿼리를 입력하세요
# 마크 모시즈
# 솔라쿼리를 입력하세요
# 피터 사스가드
# 솔라쿼리를 입력하세요
# 엘리어스 코티스
# 솔라쿼리를 입력하세요
# 에이미 세이메츠
# 솔라쿼리를 입력하세요
# 벡스 테일러 클라우스
# 솔라쿼리를 입력하세요
# 줄리아 사라 스톤
# 솔라쿼리를 입력하세요
# 휴 딜런
# 솔라쿼리를 입력하세요
# 아론 더글러스
# 솔라쿼리를 입력하세요
# 벤 코튼
# 솔라쿼리를 입력하세요
# 마이클 코프사
# 솔라쿼리를 입력하세요
# 가나가와 히로
# 솔라쿼리를 입력하세요
# 라이언 로빈스
# 솔라쿼리를 입력하세요
# 니콜라스 레아
# 솔라쿼리를 입력하세요
# 그레이스 자브리스키
# 솔라쿼리를 입력하세요
# 브렌단 플레처
# 솔라쿼리를 입력하세요
# 잉그리드 토런스
# 솔라쿼리를 입력하세요
# 소냐 살로마
# 솔라쿼리를 입력하세요
# 폴 맥길리온
# 솔라쿼리를 입력하세요
# 조나단 워커
# 솔라쿼리를 입력하세요
# 조안 알렌
# 솔라쿼리를 입력하세요
# 이브 하로우
# 솔라쿼리를 입력하세요
# 레비 미든
# 솔라쿼리를 입력하세요
# 스털링 보먼
# 솔라쿼리를 입력하세요
# 마린 아일랜드
# 솔라쿼리를 입력하세요
# 서지 하우드
# 솔라쿼리를 입력하세요
# 시아란 힌즈
# 솔라쿼리를 입력하세요
# 폴 레디
# 솔라쿼리를 입력하세요
# 아담 나게이티스
# 솔라쿼리를 입력하세요
# 니브 닐센
# 솔라쿼리를 입력하세요
# 이안 하트
# 솔라쿼리를 입력하세요
# 매튜 맥널티
# 솔라쿼리를 입력하세요
# 스케자네 키키
# 솔라쿼리를 입력하세요
# DONE !!!!!
